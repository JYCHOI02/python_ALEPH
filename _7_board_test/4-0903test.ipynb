# %%
import requests

url = "http://localhost:5678/webhook-test/37c6e129-f184-4112-909b-dcfbab41a054"
payload = {"ip": "1.2.3.4", "level": 10, "rule": "5712"}
r = requests.post(url, json=payload)
print(r.status_code)   # 200
# Out:
# ---------------------------------------------------------------------------
# LocationParseError                        Traceback (most recent call last)
# File ~\Desktop\ALEPH_cjy\git_local\.venv\Lib\site-packages\urllib3\util\url.py:438, in parse_url(url)
#     436     port_int = None
# --> 438 host = _normalize_host(host, scheme)
#     440 if normalize_uri and path:
#
# File ~\Desktop\ALEPH_cjy\git_local\.venv\Lib\site-packages\urllib3\util\url.py:324, in _normalize_host(host, scheme)
#     322         elif not _IPV4_RE.match(host):
#     323             return to_str(
# --> 324                 b".".join([_idna_encode(label) for label in host.split(".")]),
#     325                 "ascii",
#     326             )
#     327 return host
#
# File ~\Desktop\ALEPH_cjy\git_local\.venv\Lib\site-packages\urllib3\util\url.py:342, in _idna_encode(name)
#     341     except idna.IDNAError:
# --> 342         raise LocationParseError(
# ...

# %%
# detect.py  — 경보 분류 스크립트
alerts = [
    {"level": 12, "ip": "1.1.1.1"},
    {"level": 9,  "ip": "2.2.2.2"},
    {"level": 5,  "ip": "3.3.3.3"},
]

def severity(level):
    if level >= 10: return "High"
    if level >= 7:  return "Medium"
    return "Low"

for a in alerts:
    print(f'{a["ip"]} → {severity(a["level"])}')
# Out:
# 1.1.1.1 → High
# 2.2.2.2 → Medium
# 3.3.3.3 → Low
